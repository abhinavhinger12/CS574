# %%
import torch
import torch.nn as nn
import torchvision.datasets as dsets
import torchvision.transforms as transforms
from torch.autograd import Variable
from torch.nn import functional as F
import matplotlib.pyplot as plt
from statistics import mean

import PIL
import matplotlib.pyplot as plt
import seaborn as sns
from model import *

# %%
input_size = 784
inter = 56
num_classes = 10
num_epochs = 50
batch_size = 100
learning_rate = 0.01
momentum = 0.5

# %%
# MNIST Dataset (Images and Labels)
train_dataset = dsets.MNIST(root='./files', 
                            train=True, 
                            transform=transforms.ToTensor(),
                            download=True)

test_dataset = dsets.MNIST(root='./files', 
                           train=False, 
                           transform=transforms.ToTensor(),
                           download=True)

# Dataset Loader (Input Pipline)
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=batch_size, 
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                          batch_size=batch_size, 
                                          shuffle=False)

# %% [markdown]
# ## Exploring the Data

# %%
train_count = [0 for x in range(0,10)]
for i,l in train_dataset:
    train_count[l] += 1

# %%
print(train_count)
# Out:
# [5923, 6742, 5958, 6131, 5842, 5421, 5918, 6265, 5851, 5949]

# %%
plt.plot(train_count)

# %%
test_count = [0 for x in range(0,10)]
for i,l in test_dataset:
    test_count[l] += 1

# %%
plt.plot(test_count,color = 'red')

# %% [markdown]
# Test data is representative of the Train Data. However the classes are imbalanced.

# %%
train_image_zero, train_label_zero = train_dataset[0]

# %%
image = transforms.ToPILImage(mode='L')(train_image_zero)

# %%
plt.imshow(image)

# %%
train_label_zero
# Out:
# 5

# %%
# Out:
# <generator object Module.parameters at 0x7f54a0e5c468>
